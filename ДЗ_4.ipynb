# %% [markdown]
# <a href="https://colab.research.google.com/github/alinarogova/HW/blob/master/%D0%94%D0%97_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Імпорт модулів та даних

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module2/data/possum.csv")

# %%
df.head()
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %% [markdown]
# # Завдання 1
# Виведіть основні числові характеристики для числових ознак

# %%
df.describe()
# Out:
#              case        site         age     hdlngth      skullw    totlngth  \
# count  104.000000  104.000000  102.000000  104.000000  104.000000  104.000000
# mean    52.500000    3.625000    3.833333   92.602885   56.883654   87.088462
# std     30.166206    2.349086    1.909244    3.573349    3.113426    4.310549
# min      1.000000    1.000000    1.000000   82.500000   50.000000   75.000000
# 25%     26.750000    1.000000    2.250000   90.675000   54.975000   84.000000
# 50%     52.500000    3.000000    3.000000   92.800000   56.350000   88.000000
# 75%     78.250000    6.000000    5.000000   94.725000   58.100000   90.000000
# max    104.000000    7.000000    9.000000  103.100000   68.600000   96.500000
#
#             taill    footlgth    earconch         eye       chest       belly
# count  104.000000  103.000000  104.000000  104.000000  104.000000  104.000000
# mean    37.009615   68.459223   48.130769   15.046154   27.000000   32.586538
# ...

# %% [markdown]
# # Завдання 2
# Проаналізуйте стовпчик `case`, чи є він інформативним?

# %%
#ні, це просто індекс
df.drop('case', axis=1, inplace=True)

# %% [markdown]
# # Завдання 3
# Очистіть дані від викидів. Виведіть очищений датафрейм

# %%
for col in df.columns:
  df.plot(kind='box', vert=False, figsize=(14,6))
  plt.title(col)
  #plt.xticks(rotation=90)

# %% [markdown]
# Дивлячись на ящик з вусами, я не бачу таких великих викидів, щоб їх чистити

# %% [markdown]
# # Завдання 4
# Для одного з числових стовпчиків вивести гістограму та ящик з вусами

# %%
df["totlngth"].plot(kind="hist", figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["totlngth"].plot(kind="box", vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# # Завдання 5
# Намалюйте матрицб кореляцій. Для найбільш корельованих ознак намалюйте точкову діаграму.

# %%
corr = df.select_dtypes(include='number').corr(method='pearson')

corr
# Out:
#               site       age   hdlngth    skullw  totlngth     taill  \
# site      1.000000 -0.131423 -0.163646 -0.083548 -0.260843  0.380444
# age      -0.131423  1.000000  0.319022  0.285107  0.260280  0.118241
# hdlngth  -0.163646  0.319022  1.000000  0.710827  0.691094  0.287429
# skullw   -0.083548  0.285107  0.710827  1.000000  0.526413  0.255921
# totlngth -0.260843  0.260280  0.691094  0.526413  1.000000  0.565646
# taill     0.380444  0.118241  0.287429  0.255921  0.565646  1.000000
# footlgth -0.783009  0.126190  0.391605  0.275059  0.444832 -0.126277
# earconch -0.790716  0.053405  0.121463 -0.000537  0.154484 -0.385136
# eye      -0.036987  0.235553  0.347175  0.321991  0.247786  0.198134
# chest    -0.345494  0.334209  0.631498  0.629737  0.577890  0.174997
# belly    -0.175266  0.354298  0.562663  0.451838  0.519465  0.294493
#
#           footlgth  earconch       eye     chest     belly
# site     -0.783009 -0.790716 -0.036987 -0.345494 -0.175266
# ...

# %%
fig = plt.figure(figsize=(8, 8))
plt.matshow(corr, cmap='RdBu', fignum=False)

# підписи для рядків та стовпчиків матриці
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr.columns)), corr.columns)

# кольорова панель
plt.colorbar()
plt.clim(-1, 1)

# %%
df.columns
# Out:
# Index(['site', 'Pop', 'sex', 'age', 'hdlngth', 'skullw', 'totlngth', 'taill',
#        'footlgth', 'earconch', 'eye', 'chest', 'belly'],
#       dtype='object')

# %%
df.plot(kind='scatter', x='skullw', y='hdlngth')
# Out:
# <Axes: xlabel='skullw', ylabel='hdlngth'>

# %%
df.plot(kind='scatter', x='footlgth', y='site')
# Out:
# <Axes: xlabel='footlgth', ylabel='site'>

# %% [markdown]
# # Завдання 6
# Для 4-ох числових ознак на вибір намалюйте ящики з вусами згрупованими по статі. Подумайте чи є вплив статі на розміри опосума

# %%
'''
df['hdlngth', 'skullw', 'totlngth', 'taill'].boxplot()
'''
for col in ('hdlngth', 'skullw', 'totlngth', 'taill'):

  df.boxplot(by='sex', column=col)
  plt.show()
